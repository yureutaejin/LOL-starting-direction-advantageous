# %%
# Library
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns

import random
from sklearn import *
import statsmodels.api as sm

# %%
# import dataframe
df = pd.read_csv('data/Challenger_Ranked_Games.csv')
df
# Out:
#            gameId  gameDuraton  blueWins  blueFirstBlood  blueFirstTower  \
# 0      4247263043         1323         0               1               0
# 1      4247155821         1317         1               0               0
# 2      4243963257          932         0               0               0
# 3      4241678498         2098         0               0               0
# 4      4241538868         2344         1               1               1
# ...           ...          ...       ...             ...             ...
# 26899  4143231833         1468         0               1               0
# 26900  4157911901          970         0               1               1
# 26901  3764171638         1480         0               1               1
# 26902  4110201724         1837         1               1               0
# 26903  4100240254          948         1               1               1
#
#        blueFirstBaron  blueFirstDragon  blueFirstInhibitor  blueDragonKills  \
# ...

# %%
# description
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26904 entries, 0 to 26903
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gameId                   26904 non-null  int64
#  1   gameDuraton              26904 non-null  int64
#  2   blueWins                 26904 non-null  int64
#  3   blueFirstBlood           26904 non-null  int64
#  4   blueFirstTower           26904 non-null  int64
#  5   blueFirstBaron           26904 non-null  int64
#  6   blueFirstDragon          26904 non-null  int64
#  7   blueFirstInhibitor       26904 non-null  int64
#  8   blueDragonKills          26904 non-null  int64
#  9   blueBaronKills           26904 non-null  int64
#  10  blueTowerKills           26904 non-null  int64
#  11  blueInhibitorKills       26904 non-null  int64
#  12  blueWardPlaced           26904 non-null  int64
#  13  blueWardkills            26904 non-null  int64
# ...

# %%
# 표본선택
sample_record = []

while (len(sample_record) != 200):
    rand_num = random.randint(0,26903)
    
    if (rand_num in sample_record):
        continue
    else:
        sample_record.append(rand_num)

sample_df = df.loc[sample_record]
sample_df.sort_index(ascending = True, inplace = True)

# %%
sample_df
# Out:
#            gameId  gameDuraton  blueWins  blueFirstBlood  blueFirstTower  \
# 327    4174637416         1559         0               1               1
# 494    4215316652          917         1               1               1
# 547    4218540056         1656         0               0               0
# 553    4214936649         1397         1               1               1
# 969    4231893867          968         1               0               1
# ...           ...          ...       ...             ...             ...
# 25840  4089207099          692         0               1               1
# 26127  4182011572          932         1               0               1
# 26372  4058284538          638         0               0               0
# 26540  4115435930         2270         0               0               0
# 26598  4150564249          906         0               0               0
#
#        blueFirstBaron  blueFirstDragon  blueFirstInhibitor  blueDragonKills  \
# ...

# %%
blue_sample = sample_df.loc[:,'blueWins':'blueObjectDamageDealt']
red_sample = sample_df.loc[:,'redWins':'redObjectDamageDealt']

# %%
# 승패와 column간 상관관계 확인
(blue_sample.select_dtypes(['int64', 'float64']).corr()).loc['blueWins']
# (red_sample.select_dtypes(['int64', 'float64']).corr()).loc['redWins']
# Out:
# blueWins                   1.000000
# blueFirstBlood             0.160464
# blueFirstTower             0.389860
# blueFirstBaron             0.206300
# blueFirstDragon            0.263416
# blueFirstInhibitor         0.643740
# blueDragonKills            0.385308
# blueBaronKills             0.231629
# blueTowerKills             0.661727
# blueInhibitorKills         0.594716
# blueWardPlaced             0.015630
# blueWardkills              0.006123
# blueKills                  0.381021
# blueDeath                 -0.439587
# blueAssist                 0.310048
# blueChampionDamageDealt    0.127209
# blueTotalGold              0.188135
# blueTotalMinionKills       0.041231
# blueTotalLevel             0.159951
# blueAvgLevel               0.159951
# blueJungleMinionKills      0.178448
# blueKillingSpree           0.399106
# blueTotalHeal              0.156261
# blueObjectDamageDealt      0.475951
# Name: blueWins, dtype: float64

# %%
# 승패와 column간 logistic regression
regression_blue_df = blue_sample.drop(columns = ['blueFirstBlood', 'blueFirstTower', 'blueFirstDragon', 'blueFirstInhibitor'])
regression_red_df = red_sample.drop(columns = ['redFirstBlood', 'redFirstTower', 'redFirstDragon', 'redFirstInhibitor'])

# %%
logit = sm.Logit(regression_blue_df['blueWins'],reg_df[reg_df.columns.tolist()[:-2]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-848bb137d829> in <module>
# ----> 1 logit = sm.Logit(regression_blue_df['blueWins'],reg_df[reg_df.columns.tolist()[:-2]])
#
# NameError: name 'reg_df' is not defined
